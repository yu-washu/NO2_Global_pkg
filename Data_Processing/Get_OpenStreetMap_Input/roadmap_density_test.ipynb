# %%
import numpy as np

# %%
def load_NA_road_map(YEAR,entry):
    indir = '/Volumes/rvmartin2/Active/yany1/1.project/NO2_DL_US_2019/NO2_US_pkg/Input_variables/OpenStreetMap_RoadDensity_input/' + '{}/'.format(YEAR)
    infile = indir + 'OpenStreetMap-US-{}-RoadDensityMap_{}.npy'.format(entry,YEAR)
    RoadDensityMap = np.load(infile)
    return RoadDensityMap

entry_list = ['motorway','primary','secondary','trunk','unclassified','residential']

# %%
motorway_map = load_NA_road_map(2025,'motorway')

# %%
len(np.where(motorway_map>0)[0])
# Out:
# 131879

# %%
np.where(motorway_map==np.max(motorway_map))
# Out:
# (array([2283]), array([3308]))

# %%
lat = np.linspace(10.005,69.995,6000)
lon = np.linspace(-169.995,-40.005,13000)
print(lat[2283])
print(lon[3308])

# %%
primary_map = load_NA_road_map(2025,'primary')
secondary_map = load_NA_road_map(2025,'secondary')
trunk_map = load_NA_road_map(2025,'trunk')
unclassified_map = load_NA_road_map(2025,'unclassified')
