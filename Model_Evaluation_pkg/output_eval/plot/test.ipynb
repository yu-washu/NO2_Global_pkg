# %%
import numpy as np
import pandas as pd

# %%
InDir = '/storage1/fs1/rvmartin2/Active/yany1/1.project/NO2_DL_global/Training_Evaluation_Estimation/NO2/LightGBM_1006/Uncertainty_Results/LOWESS_values_bins/'
LOWESS_file = InDir + 'BLISCO_LOWESS_values_frac-0.3_LightGBM_1006_NO2_10-folds_5-SeedsNumbers_0-500km-51bins_mean-Mode_5-NearbySites_2019-2019_27channels_5x5_BenchMark.npy'
rRMSE_file = InDir + 'BLISCO_rRMSE_LightGBM_1006_NO2_10-folds_5-SeedsNumbers_0-500km-51bins_mean-Mode_5-NearbySites_2019-2019_27channels_5x5_BenchMark.npy'

# %%
LOWESS = np.load(LOWESS_file, allow_pickle=True)
rRMSE = np.load(rRMSE_file,allow_pickle=True)

# %%
print(LOWESS)
# Out:
# {'Jan': array([0.23627186, 0.23799203, 0.23966223, 0.24127293, 0.24283799,
#        0.2443626 , 0.24585514, 0.24734628, 0.24816619, 0.24836994,
#        0.24805715, 0.24725506, 0.24597671, 0.24468435, 0.24366716,
#        0.24302627, 0.24271126, 0.24264662, 0.24313397, 0.24435057,
#        0.24603243, 0.2477896 , 0.24941062, 0.2507907 , 0.25194354,
#        0.25284088, 0.25344895, 0.25386226, 0.25405876, 0.25420745,
#        0.25428964, 0.25423878, 0.25417004, 0.25420582, 0.25440267,
#        0.25470018, 0.25495808, 0.25510609, 0.25529176, 0.25564518,
#        0.25619891, 0.25704351, 0.25813177, 0.25950741, 0.26085777,
#        0.26220984, 0.26358697, 0.26499998, 0.2664449 , 0.26790882]), 'Feb': array([0.2648241 , 0.26822684, 0.27149128, 0.27466764, 0.27782125,
#        0.28097455, 0.28406785, 0.28688098, 0.28836572, 0.28936168,
#        0.2904036 , 0.29155147, 0.29238922, 0.2928021 , 0.29281609,
#        0.29308645, 0.29384001, 0.29491996, 0.29622601, 0.29752278,
# ...

# %%
print(rRMSE)
# Out:
# {'Jan': array([0.18984301, 0.20774477, 0.23639885, 0.25225115, 0.25808903,
#        0.24261541, 0.24972417, 0.23443591, 0.25102163, 0.25710978,
#        0.25002131, 0.24567425, 0.24979873, 0.24818118, 0.23712916,
#        0.23725837, 0.23379841, 0.24193501, 0.24367631, 0.24258592,
#        0.2536964 , 0.24531347, 0.24040795, 0.25956034, 0.25248984,
#        0.25418681, 0.25512923, 0.25684594, 0.25511625, 0.25193456,
#        0.25181048, 0.24944851, 0.26248889, 0.253992  , 0.25922878,
#        0.25072662, 0.25353498, 0.25657342, 0.25307924, 0.25542947,
#        0.25527064, 0.25985355, 0.25362799, 0.26046327, 0.25697028,
#        0.26042101, 0.26598337, 0.27023791, 0.26113251, 0.26961878]), 'Feb': array([0.21187528, 0.25461441, 0.27181819, 0.28689979, 0.29032889,
#        0.2738855 , 0.29518163, 0.27274045, 0.28736352, 0.31575649,
#        0.30627291, 0.29536776, 0.28640119, 0.29557039, 0.28939157,
#        0.29368381, 0.29261438, 0.28748891, 0.29219661, 0.30437415,
# ...
